# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd gdrive/My\ Drive/machina/
# %ls
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# [Errno 2] No such file or directory: 'gdrive/My Drive/machina/'
# /content/gdrive/My Drive/machina
# aman.png         pretrained_model/               result.png
# colab_run.ipynb  quick_styledna_inference.ipynb  saved_models/
# dad.png          readme.md                       scripts/
# ex-machina.jpg   recognizing-faces-in-the-wild/  styledna/
# Lauren.png       result/                         test/
# mom.png          result_male_15.png              vae_inference.py

# %%
#!pip install gdown
# !gdown https://drive.google.com/u/0/uc?id=1cFC5j8PyZYwy5pAW5AZDBDqvSnh31SsA&export=download
# !gdown https://drive.google.com/u/0/uc?id=1doaaGITOk9TMK_cPsJhqWim7j0exZRpc&export=download
# !gdown https://drive.google.com/u/0/uc?id=1orcyIN79yk2VvDQ0mtdr7FP_64DKcOWo&export=download
# !gdown https://drive.google.com/u/0/uc?id=1UKZ68Hhu8OqAzOEmhqTieWVxnf8CsdHf&export=download
# !gdown https://drive.google.com/u/0/uc?id=1p4K_fMSUpTsRqW_EefFH72u3Mxw5BDrb&export=download
# !gdown https://drive.google.com/u/0/uc?id=1WkzDLVe5O5lo_hV7AVBzJ41RuDEMnDQb&export=download
# !gdown https://drive.google.com/u/0/uc?id=1AmXuxJ-qrtBW4YVUWzVf5Y4ZxLNC65cq&export=download
# !gdown https://drive.google.com/uc?id=1eu681cAgKyAnBTN7gsSG6BNgPf1O9P3q&export=download
# Out:
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1cFC5j8PyZYwy5pAW5AZDBDqvSnh31SsA
# To: /content/gdrive/MyDrive/machina/enc_4_2.pth
# 100% 164M/164M [00:03<00:00, 49.5MB/s]
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1doaaGITOk9TMK_cPsJhqWim7j0exZRpc
# To: /content/gdrive/MyDrive/machina/condi_4_2.pth
# 100% 10.1M/10.1M [00:00<00:00, 66.9MB/s]
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1orcyIN79yk2VvDQ0mtdr7FP_64DKcOWo
# To: /content/gdrive/MyDrive/machina/60.pth
# 100% 6.35M/6.35M [00:00<00:00, 19.6MB/s]
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1UKZ68Hhu8OqAzOEmhqTieWVxnf8CsdHf
# To: /content/gdrive/MyDrive/machina/stylegan2-ffhq-config-f.pt
# 100% 381M/381M [00:06<00:00, 57.1MB/s]
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1p4K_fMSUpTsRqW_EefFH72u3Mxw5BDrb
# To: /content/gdrive/MyDrive/machina/shape_predictor_68_face_landmarks.dat
# 100% 99.7M/99.7M [00:02<00:00, 39.5MB/s]
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1WkzDLVe5O5lo_hV7AVBzJ41RuDEMnDQb
# To: /content/gdrive/MyDrive/machina/mom.png
# 100% 78.6k/78.6k [00:00<00:00, 4.15MB/s]
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1AmXuxJ-qrtBW4YVUWzVf5Y4ZxLNC65cq
# To: /content/gdrive/MyDrive/machina/dad.png
# 100% 84.9k/84.9k [00:00<00:00, 31.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1eu681cAgKyAnBTN7gsSG6BNgPf1O9P3q
# To: /content/gdrive/MyDrive/machina/vae_5000.pth
# 100% 8.45M/8.45M [00:00<00:00, 86.3MB/s]

# %%
# !pip install ninja
# !pip install dlib
# !pip install -q gwpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ninja
#   Downloading ninja-1.11.1-py2.py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 kB 13.4 MB/s eta 0:00:00
# Installing collected packages: ninja
# Successfully installed ninja-1.11.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: dlib in /usr/local/lib/python3.9/dist-packages (19.24.1)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 52.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 6.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for
#           7.5603e-01, -4.7575e-01,  3.2148e-02,  6.6853e-01,  2.7902e-01,
#          -8.0006e-02, -3.3461e-01,  3.1492e-01,  8.1467e-01, -2.6891e-01,
#           9.6024e-01,  4.3477e-01,  6.6615e-02,  7.6565e-01,  1.8592e-01,
#           3.4386e-01, -3.9654e-01, -2.4040e-01,  6.6543e-02,  1.9387e-01,
#          -1.9802e-01,  4.9881e-01]], device='cuda:0')

# %%
import PIL

# %%
# !python3 styledna/og_inference.py -m ./mom.png -d ./dad.png -o ./
# Out:
# Loading encoder weights from ckpt!
# Loading decoder weights from pretrained!

# %%
child = PIL.Image.open("./result.png")
print("Unmasked image")
child
# Out:
# Unmasked image
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7F039C7C0700>

# %%
child = PIL.Image.open("./result.png")
print("randomly masked image")
child
# Out:
# randomly masked image
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7F046AB8DE50>

# %%
child = PIL.Image.open("./result.png")
print("randomly masked image2")
child
# Out:
# randomly masked image2
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7F039C7C04F0>

# %%
child = PIL.Image.open("./result.png")
print("randomly masked image3")
child
# Out:
# randomly masked image3
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7F039C7C0820>

# %%
child = PIL.Image.open("./result.png")
print("randomly masked image4")
child
# Out:
# randomly masked image4
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7F039C7C09A0>

# %%
child = PIL.Image.open("./result.png")
print("randomly masked image")
child
# Out:
# randomly masked image
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7F039C7C09D0>

# %%
# !python3 styledna/mask_inference2.py -m ./mom.png -d ./dad.png -o ./
# Out:
# Loading encoder weights from ckpt!
# Loading decoder weights from pretrained!
# MASK VECTOR torch.Size([1, 512])

# %%
child = PIL.Image.open("./result.png")
print("first half masked image")
child
# Out:
# first half masked image
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7F039C7C0730>

# %%
# !python3 styledna/mask_inference.py -m ./mom.png -d ./dad.png -o ./

# %%
child = PIL.Image.open("./result.png")
print("second half masked image")
child
# Out:
# second half masked image
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7F039C78CD00>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd gdrive/My\ Drive/machina/
import PIL
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/machina

# %%
# !python3 styledna/mask_inference.py -m ./mom.png -d ./dad.png -o ./
# Out:
# Loading encoder weights from ckpt!
# Loading decoder weights from pretrained!

# %%
child = PIL.Image.open("./result.png")
print("50 most important features found using L1 reg image")
child
# Out:
# 50 most important features found using L1 reg image
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7F4F65975D00>

# %%
# !python3 styledna/mask_inference.py -m ./mom.png -d ./dad.png -o ./
child = PIL.Image.open("./result.png")
print("50 most important features found using L1 reg image")
child
# Out:
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# Traceback (most recent call last):
#   File "/content/gdrive/MyDrive/machina/styledna/mask_inference.py", line 6, in <module>
#     from model.model import pSp, condi
#   File "/content/gdrive/MyDrive/machina/styledna/model/model.py", line 8, in <module>
#     from stylegan2.model import EqualLinear, Generator
#   File "/content/gdrive/MyDrive/machina/styledna/stylegan2/model.py", line 7, in <module>
#     from stylegan2.op import FusedLeakyReLU, fused_leaky_relu, upfirdn2d
#   File "/content/gdrive/MyDrive/machina/styledna/stylegan2/op/__init__.py", line 1, in <module>
#     from .fused_act import FusedLeakyReLU, fused_leaky_relu
#   File "/content/gdrive/MyDrive/machina/styledna/stylegan2/op/fused_act.py", line 9, in <module>
#     fused = load(
#   File "/usr/local/lib/python3.9/dist-packages/torch/utils/cpp_extension.py", line 1284, in load
#     return _jit_compile(
#   File "/usr/local/lib/python3.9/dist-packages/torch/utils/cpp_extension.py", line 1509, in _jit_compile
#     _write_ninja_file_and_build_library(
#   File "/usr/local/lib/python3.9/dist-packages/torch/utils/cpp_extension.py", line 1593, in _write_ninja_file_and_build_library
#     verify_ninja_availability()
#   File "/usr/local/lib/python3.9/dist-packages/torch/utils/cpp_extension.py", line 1649, in verify_ninja_availability
#     raise RuntimeError("Ninja is required to load C++ extensions")
# RuntimeError: Ninja is required to load C++ extensions
# 50 most important features found using L1 reg image
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7FF448331850>
