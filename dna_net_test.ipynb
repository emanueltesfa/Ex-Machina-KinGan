# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd gdrive/My\ Drive/machina/
# %ls
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# [Errno 2] No such file or directory: 'gdrive/My Drive/machina/'
# /
# bin@      dev/   lib32@   mnt/                      python-apt/  srv/    usr/
# boot/     etc/   lib64@   NGC-DL-CONTAINER-LICENSE  root/        sys/    var/
# content/  home/  libx32@  opt/                      run/         tmp/
# datalab/  lib@   media/   proc/                     sbin@        tools/

# %%
# !pip install ninja
# !pip install dlib
# !pip install -q gwpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python3 styledna/og_inference.py -m ./mom.png -d ./dad.png -o ./
# Out:
# python3: can't open file '//styledna/og_inference.py': [Errno 2] No such file or directory

# %%
import PIL
image = PIL.Image.open("./result.png")
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7F7CF20CC550>

# %%
# !python3 styledna/og_inference.py -m ./mom.png -d ./dad.png -o ./
# Out:
# Loading encoder weights from ckpt!
# Loading decoder weights from pretrained!
# cuda
# True True True
# torch.float32 torch.Size([1, 512]) torch.float32 torch.Size([1, 512])

# %%
import PIL
image = PIL.Image.open("./result.png")
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7FCC82995870>

# %%
# !python3 styledna/og_inference.py -m ./mom.png -d ./dad.png -o ./
import PIL
image = PIL.Image.open("./result.png")
image
# Out:
# Loading encoder weights from ckpt!
# Loading decoder weights from pretrained!
# cuda
# True True True
# torch.float32 torch.Size([1, 512]) torch.float32 torch.Size([1, 512])
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7FCC8382F5E0>

# %%
# !python3 styledna/og_inference.py -m ./mom.png -d ./dad.png -o ./
import PIL
image = PIL.Image.open("./result.png")
image
# Out:
# Loading encoder weights from ckpt!
# Loading decoder weights from pretrained!
# cuda
# True True True
# torch.float32 torch.Size([1, 512]) torch.float32 torch.Size([1, 512])
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7FCC82996E00>

# %%
for i in range(5):
  # !python3 styledna/og_inference.py -m ./mom.png -d ./dad.png -o ./
  image = PIL.Image.open("./result.png")
  image
# Out:
# Loading encoder weights from ckpt!
# Loading decoder weights from pretrained!
# cuda
# True True True
# torch.float32 torch.Size([1, 512]) torch.float32 torch.Size([1, 512])
# Loading encoder weights from ckpt!
# Loading decoder weights from pretrained!
# cuda
# True True True
# torch.float32 torch.Size([1, 512]) torch.float32 torch.Size([1, 512])
# Loading encoder weights from ckpt!
# Loading decoder weights from pretrained!
# cuda
# True True True
# torch.float32 torch.Size([1, 512]) torch.float32 torch.Size([1, 512])
# Loading encoder weights from ckpt!
# Loading decoder weights from pretrained!
# cuda
# True True True
# torch.float32 torch.Size([1, 512]) torch.float32 torch.Size([1, 512])
# Loading encoder weights from ckpt!
# Loading decoder weights from pretrained!
# cuda
# True True True
# torch.float32 torch.Size([1, 512]) torch.float32 torch.Size([1, 512])

# %%
image = PIL.Image.open("./result.png")
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7FCC82A42B60>

# %%
# !python3 styledna/og_inference.py -m ./mom.png -d ./dad.png -o ./
# Out:
# Loading encoder weights from ckpt!
# Loading decoder weights from pretrained!
# cuda
# True True True
# torch.float32 torch.Size([1, 512]) torch.float32 torch.Size([1, 512])

# %%
import PIL
image = PIL.Image.open('./result.png')
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7FCC82A40790>

# %%
# !python scripts\generate_fiw_triplets.py
# Out:
# python3: can't open file '/content/scriptsgenerate_fiw_triplets.py': [Errno 2] No such file or directory

# %%
# !python3 styledna\vae_inference.py
# Out:
# python3: can't open file '/content/stylednavae_inference.py': [Errno 2] No such file or directory

# %%
# Out:
# bin@      dev/   lib32@   mnt/                      python-apt/  srv/    usr/
# boot/     etc/   lib64@   NGC-DL-CONTAINER-LICENSE  root/        sys/    var/
# content/  home/  libx32@  opt/                      run/         tmp/
# datalab/  lib@   media/   proc/                     sbin@        tools/
# /
# bin@      dev/   lib32@   mnt/                      python-apt/  srv/    usr/
# boot/     etc/   lib64@   NGC-DL-CONTAINER-LICENSE  root/        sys/    var/
# content/  home/  libx32@  opt/                      run/         tmp/
# datalab/  lib@   media/   proc/                     sbin@        tools/
